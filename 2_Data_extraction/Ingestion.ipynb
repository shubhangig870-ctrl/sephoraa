# %%
data_source = "brands"
catalog = "sephoraa"
bronze_schema = "bronze"
# Define S3 path
bucket = "sephoraa"
prefix = f"source_row_data/{data_source}"
s3_path = f"s3://{bucket}/{prefix}/"

# Use dbutils to list files and find the latest
files = dbutils.fs.ls(s3_path)
latest_file = sorted(files, key=lambda x: x.modificationTime, reverse=True)[0]

base_path = latest_file.path
print("Latest file path:", base_path)

from pyspark.sql import functions as F
df = (
    spark.read.format("csv")
       .option("header",True)
       .option("inferSchema",True)
       .load(base_path)
       .withColumn("current_date",F.current_date())
       .withColumn("read_timestamp",F.current_timestamp())
       .select("*","_metadata.file_name","_metadata.file_size")
    )
print(df.count())
display(df.limit(10))

#
df.write\
    .format("delta")\
            .mode("overwrite")\
                .saveAsTable(f"{catalog}.{bronze_schema}.{data_source}")
# .option("delta.enableChangeDataFeed","true")\

# # bronze write to s3
df.write.format("delta")\
    .option("overwriteSchema","true")\
    .mode("overwrite")\
    .partitionBy("current_date")\
    .save(f"s3://sephoraa/bronz_row_deta/{data_source}/")
    
   # s3://sephoraa/source_row_data/

# %%
data_source = "categories"
catalog = "sephoraa"
bronze_schema = "bronze"
# Define S3 path
bucket = "sephoraa"
prefix = f"source_row_data/{data_source}"
s3_path = f"s3://{bucket}/{prefix}/"

# Use dbutils to list files and find the latest
files = dbutils.fs.ls(s3_path)
latest_file = sorted(files, key=lambda x: x.modificationTime, reverse=True)[0]

base_path = latest_file.path
print("Latest file path:", base_path)

from pyspark.sql import functions as F
df = (
    spark.read.format("csv")
       .option("header",True)
       .option("inferSchema",True)
       .load(base_path)
       .withColumn("current_date",F.current_date())
       .withColumn("read_timestamp",F.current_timestamp())
       .select("*","_metadata.file_name","_metadata.file_size")
    )
print(df.count())
display(df.limit(10))

#
df.write\
    .format("delta")\
            .mode("overwrite")\
                .saveAsTable(f"{catalog}.{bronze_schema}.{data_source}")
# .option("delta.enableChangeDataFeed","true")\

# # bronze write to s3
df.write.format("delta")\
    .option("overwriteSchema","true")\
    .mode("overwrite")\
    .partitionBy("current_date")\
    .save(f"s3://sephoraa/bronz_row_deta/{data_source}/")
    
   # s3://sephoraa/source_row_data/

# %%
data_source = "customer_addresses"
catalog = "sephoraa"
bronze_schema = "bronze"
# Define S3 path
bucket = "sephoraa"
prefix = f"source_row_data/{data_source}"
s3_path = f"s3://{bucket}/{prefix}/"

# Use dbutils to list files and find the latest
files = dbutils.fs.ls(s3_path)
latest_file = sorted(files, key=lambda x: x.modificationTime, reverse=True)[0]

base_path = latest_file.path
print("Latest file path:", base_path)

from pyspark.sql import functions as F
df = (
    spark.read.format("csv")
       .option("header",True)
       .option("inferSchema",True)
       .load(base_path)
       .withColumn("current_date",F.current_date())
       .withColumn("read_timestamp",F.current_timestamp())
       .select("*","_metadata.file_name","_metadata.file_size")
    )
print(df.count())
display(df.limit(10))

#
df.write\
    .format("delta")\
            .mode("overwrite")\
                .saveAsTable(f"{catalog}.{bronze_schema}.{data_source}")
# .option("delta.enableChangeDataFeed","true")\

# # bronze write to s3
df.write.format("delta")\
    .option("overwriteSchema","true")\
    .mode("overwrite")\
    .partitionBy("current_date")\
    .save(f"s3://sephoraa/bronz_row_deta/{data_source}/")
    
   # s3://sephoraa/source_row_data/

# %%
data_source = "customers"
catalog = "sephoraa"
bronze_schema = "bronze"
# Define S3 path
bucket = "sephoraa"
prefix = f"source_row_data/{data_source}"
s3_path = f"s3://{bucket}/{prefix}/"

# Use dbutils to list files and find the latest
files = dbutils.fs.ls(s3_path)
latest_file = sorted(files, key=lambda x: x.modificationTime, reverse=True)[0]

base_path = latest_file.path
print("Latest file path:", base_path)

from pyspark.sql import functions as F
df = (
    spark.read.format("csv")
       .option("header",True)
       .option("inferSchema",True)
       .load(base_path)
       .withColumn("current_date",F.current_date())
       .withColumn("read_timestamp",F.current_timestamp())
       .select("*","_metadata.file_name","_metadata.file_size")
    )
print(df.count())
display(df.limit(10))

#
df.write\
    .format("delta")\
            .mode("overwrite")\
                .saveAsTable(f"{catalog}.{bronze_schema}.{data_source}")
# .option("delta.enableChangeDataFeed","true")\

# # bronze write to s3
df.write.format("delta")\
    .option("overwriteSchema","true")\
    .mode("overwrite")\
    .partitionBy("current_date")\
    .save(f"s3://sephoraa/bronz_row_deta/{data_source}/")

# %%
data_source = "inventory"
catalog = "sephoraa"
bronze_schema = "bronze"
# Define S3 path
bucket = "sephoraa"
prefix = f"source_row_data/{data_source}"
s3_path = f"s3://{bucket}/{prefix}/"

# Use dbutils to list files and find the latest
files = dbutils.fs.ls(s3_path)
latest_file = sorted(files, key=lambda x: x.modificationTime, reverse=True)[0]

base_path = latest_file.path
print("Latest file path:", base_path)

from pyspark.sql import functions as F
df = (
    spark.read.format("csv")
       .option("header",True)
       .option("inferSchema",True)
       .load(base_path)
       .withColumn("current_date",F.current_date())
       .withColumn("read_timestamp",F.current_timestamp())
       .select("*","_metadata.file_name","_metadata.file_size")
    )
print(df.count())
display(df.limit(10))

#
df.write\
    .format("delta")\
            .mode("overwrite")\
                .saveAsTable(f"{catalog}.{bronze_schema}.{data_source}")
# .option("delta.enableChangeDataFeed","true")\

# # bronze write to s3
df.write.format("delta")\
    .option("overwriteSchema","true")\
    .mode("overwrite")\
    .partitionBy("current_date")\
    .save(f"s3://sephoraa/bronz_row_deta/{data_source}/")

# %%
data_source = "order_items"
catalog = "sephoraa"
bronze_schema = "bronze"
# Define S3 path
bucket = "sephoraa"
prefix = f"source_row_data/{data_source}"
s3_path = f"s3://{bucket}/{prefix}/"

# Use dbutils to list files and find the latest
files = dbutils.fs.ls(s3_path)
latest_file = sorted(files, key=lambda x: x.modificationTime, reverse=True)[0]

base_path = latest_file.path
print("Latest file path:", base_path)

from pyspark.sql import functions as F
df = (
    spark.read.format("csv")
       .option("header",True)
       .option("inferSchema",True)
       .load(base_path)
       .withColumn("current_date",F.current_date())
       .withColumn("read_timestamp",F.current_timestamp())
       .select("*","_metadata.file_name","_metadata.file_size")
    )
print(df.count())
display(df.limit(10))

#
df.write\
    .format("delta")\
            .mode("overwrite")\
                .saveAsTable(f"{catalog}.{bronze_schema}.{data_source}")
# .option("delta.enableChangeDataFeed","true")\

# # bronze write to s3
df.write.format("delta")\
    .option("overwriteSchema","true")\
    .mode("overwrite")\
    .partitionBy("current_date")\
    .save(f"s3://sephoraa/bronz_row_deta/{data_source}/")

# %%
data_source = "orders"
catalog = "sephoraa"
bronze_schema = "bronze"
# Define S3 path
bucket = "sephoraa"
prefix = f"source_row_data/{data_source}"
s3_path = f"s3://{bucket}/{prefix}/"

# Use dbutils to list files and find the latest
files = dbutils.fs.ls(s3_path)
latest_file = sorted(files, key=lambda x: x.modificationTime, reverse=True)[0]

base_path = latest_file.path
print("Latest file path:", base_path)

from pyspark.sql import functions as F
df = (
    spark.read.format("csv")
       .option("header",True)
       .option("inferSchema",True)
       .load(base_path)
       .withColumn("current_date",F.current_date())
       .withColumn("read_timestamp",F.current_timestamp())
       .select("*","_metadata.file_name","_metadata.file_size")
    )
print(df.count())
display(df.limit(10))

#
df.write\
    .format("delta")\
            .mode("overwrite")\
                .saveAsTable(f"{catalog}.{bronze_schema}.{data_source}")
# .option("delta.enableChangeDataFeed","true")\

# # bronze write to s3
df.write.format("delta")\
    .option("overwriteSchema","true")\
    .mode("overwrite")\
    .partitionBy("current_date")\
    .save(f"s3://sephoraa/bronz_row_deta/{data_source}/")

# %%
data_source = "page_views"
catalog = "sephoraa"
bronze_schema = "bronze"
# Define S3 path
bucket = "sephoraa"
prefix = f"source_row_data/{data_source}"
s3_path = f"s3://{bucket}/{prefix}/"

# Use dbutils to list files and find the latest
files = dbutils.fs.ls(s3_path)
latest_file = sorted(files, key=lambda x: x.modificationTime, reverse=True)[0]

base_path = latest_file.path
print("Latest file path:", base_path)

from pyspark.sql import functions as F
df = (
    spark.read.format("csv")
       .option("header",True)
       .option("inferSchema",True)
       .load(base_path)
       .withColumn("current_date",F.current_date())
       .withColumn("read_timestamp",F.current_timestamp())
       .select("*","_metadata.file_name","_metadata.file_size")
    )
print(df.count())
display(df.limit(10))

#
df.write\
    .format("delta")\
            .mode("overwrite")\
                .saveAsTable(f"{catalog}.{bronze_schema}.{data_source}")
# .option("delta.enableChangeDataFeed","true")\

# # bronze write to s3
df.write.format("delta")\
    .option("overwriteSchema","true")\
    .mode("overwrite")\
    .partitionBy("current_date")\
    .save(f"s3://sephoraa/bronz_row_deta/{data_source}/")

# %%
data_source = "payments"
catalog = "sephoraa"
bronze_schema = "bronze"
# Define S3 path
bucket = "sephoraa"
prefix = f"source_row_data/{data_source}"
s3_path = f"s3://{bucket}/{prefix}/"

# Use dbutils to list files and find the latest
files = dbutils.fs.ls(s3_path)
latest_file = sorted(files, key=lambda x: x.modificationTime, reverse=True)[0]

base_path = latest_file.path
print("Latest file path:", base_path)

from pyspark.sql import functions as F
df = (
    spark.read.format("csv")
       .option("header",True)
       .option("inferSchema",True)
       .load(base_path)
       .withColumn("current_date",F.current_date())
       .withColumn("read_timestamp",F.current_timestamp())
       .select("*","_metadata.file_name","_metadata.file_size")
    )
print(df.count())
display(df.limit(10))

#
df.write\
    .format("delta")\
            .mode("overwrite")\
                .saveAsTable(f"{catalog}.{bronze_schema}.{data_source}")
# .option("delta.enableChangeDataFeed","true")\

# # bronze write to s3
df.write.format("delta")\
    .option("overwriteSchema","true")\
    .mode("overwrite")\
    .partitionBy("current_date")\
    .save(f"s3://sephoraa/bronz_row_deta/{data_source}/")

# %%
data_source = "products"
catalog = "sephoraa"
bronze_schema = "bronze"
# Define S3 path
bucket = "sephoraa"
prefix = f"source_row_data/{data_source}"
s3_path = f"s3://{bucket}/{prefix}/"

# Use dbutils to list files and find the latest
files = dbutils.fs.ls(s3_path)
latest_file = sorted(files, key=lambda x: x.modificationTime, reverse=True)[0]

base_path = latest_file.path
print("Latest file path:", base_path)

from pyspark.sql import functions as F
df = (
    spark.read.format("csv")
       .option("header",True)
       .option("inferSchema",True)
       .load(base_path)
       .withColumn("current_date",F.current_date())
       .withColumn("read_timestamp",F.current_timestamp())
       .select("*","_metadata.file_name","_metadata.file_size")
    )
print(df.count())
display(df.limit(10))

#
df.write\
    .format("delta")\
            .mode("overwrite")\
                .saveAsTable(f"{catalog}.{bronze_schema}.{data_source}")
# .option("delta.enableChangeDataFeed","true")\

# # bronze write to s3
df.write.format("delta")\
    .option("overwriteSchema","true")\
    .mode("overwrite")\
    .partitionBy("current_date")\
    .save(f"s3://sephoraa/bronz_row_deta/{data_source}/")

# %%
data_source = "reviews"
catalog = "sephoraa"
bronze_schema = "bronze"
# Define S3 path
bucket = "sephoraa"
prefix = f"source_row_data/{data_source}"
s3_path = f"s3://{bucket}/{prefix}/"

# Use dbutils to list files and find the latest
files = dbutils.fs.ls(s3_path)
latest_file = sorted(files, key=lambda x: x.modificationTime, reverse=True)[0]

base_path = latest_file.path
print("Latest file path:", base_path)

from pyspark.sql import functions as F
df = (
    spark.read.format("csv")
       .option("header",True)
       .option("inferSchema",True)
       .load(base_path)
       .withColumn("current_date",F.current_date())
       .withColumn("read_timestamp",F.current_timestamp())
       .select("*","_metadata.file_name","_metadata.file_size")
    )
print(df.count())
display(df.limit(10))

#
df.write\
    .format("delta")\
            .mode("overwrite")\
                .saveAsTable(f"{catalog}.{bronze_schema}.{data_source}")
# .option("delta.enableChangeDataFeed","true")\

# # bronze write to s3
df.write.format("delta")\
    .option("overwriteSchema","true")\
    .mode("overwrite")\
    .partitionBy("current_date")\
    .save(f"s3://sephoraa/bronz_row_deta/{data_source}/")

# %%
data_source = "shipments"
catalog = "sephoraa"
bronze_schema = "bronze"
# Define S3 path
bucket = "sephoraa"
prefix = f"source_row_data/{data_source}"
s3_path = f"s3://{bucket}/{prefix}/"

# Use dbutils to list files and find the latest
files = dbutils.fs.ls(s3_path)
latest_file = sorted(files, key=lambda x: x.modificationTime, reverse=True)[0]

base_path = latest_file.path
print("Latest file path:", base_path)

from pyspark.sql import functions as F
df = (
    spark.read.format("csv")
       .option("header",True)
       .option("inferSchema",True)
       .load(base_path)
       .withColumn("current_date",F.current_date())
       .withColumn("read_timestamp",F.current_timestamp())
       .select("*","_metadata.file_name","_metadata.file_size")
    )
print(df.count())
display(df.limit(10))

#
df.write\
    .format("delta")\
            .mode("overwrite")\
                .saveAsTable(f"{catalog}.{bronze_schema}.{data_source}")
# .option("delta.enableChangeDataFeed","true")\

# # bronze write to s3
df.write.format("delta")\
    .option("overwriteSchema","true")\
    .mode("overwrite")\
    .partitionBy("current_date")\
    .save(f"s3://sephoraa/bronz_row_deta/{data_source}/")

# %%
data_source = "warehouses"
catalog = "sephoraa"
bronze_schema = "bronze"
# Define S3 path
bucket = "sephoraa"
prefix = f"source_row_data/{data_source}"
s3_path = f"s3://{bucket}/{prefix}/"

# Use dbutils to list files and find the latest
files = dbutils.fs.ls(s3_path)
latest_file = sorted(files, key=lambda x: x.modificationTime, reverse=True)[0]

base_path = latest_file.path
print("Latest file path:", base_path)

from pyspark.sql import functions as F
df = (
    spark.read.format("csv")
       .option("header",True)
       .option("inferSchema",True)
       .load(base_path)
       .withColumn("current_date",F.current_date())
       .withColumn("read_timestamp",F.current_timestamp())
       .select("*","_metadata.file_name","_metadata.file_size")
    )
print(df.count())
display(df.limit(10))

#
df.write\
    .format("delta")\
            .mode("overwrite")\
                .saveAsTable(f"{catalog}.{bronze_schema}.{data_source}")
# .option("delta.enableChangeDataFeed","true")\

# # bronze write to s3
df.write.format("delta")\
    .option("overwriteSchema","true")\
    .mode("overwrite")\
    .partitionBy("current_date")\
    .save(f"s3://sephoraa/bronz_row_deta/{data_source}/")

# %%
data_source = "website_sessions"
catalog = "sephoraa"
bronze_schema = "bronze"
# Define S3 path
bucket = "sephoraa"
prefix = f"source_row_data/{data_source}"
s3_path = f"s3://{bucket}/{prefix}/"

# Use dbutils to list files and find the latest
files = dbutils.fs.ls(s3_path)
latest_file = sorted(files, key=lambda x: x.modificationTime, reverse=True)[0]

base_path = latest_file.path
print("Latest file path:", base_path)

from pyspark.sql import functions as F
df = (
    spark.read.format("csv")
       .option("header",True)
       .option("inferSchema",True)
       .load(base_path)
       .withColumn("current_date",F.current_date())
       .withColumn("read_timestamp",F.current_timestamp())
       .select("*","_metadata.file_name","_metadata.file_size")
    )
print(df.count())
display(df.limit(10))

#
df.write\
    .format("delta")\
            .mode("overwrite")\
                .saveAsTable(f"{catalog}.{bronze_schema}.{data_source}")
# .option("delta.enableChangeDataFeed","true")\

# # bronze write to s3
df.write.format("delta")\
    .option("overwriteSchema","true")\
    .mode("overwrite")\
    .partitionBy("current_date")\
    .save(f"s3://sephoraa/bronz_row_deta/{data_source}/")
