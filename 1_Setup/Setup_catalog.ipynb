# %%
# %sql
CREATE CATALOG IF NOT EXISTS sephoraa;
use catalog sephoraa;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS sephoraa.bronze;
CREATE SCHEMA IF NOT EXISTS sephoraa.silver;
CREATE SCHEMA IF NOT EXISTS sephoraa.gold;
